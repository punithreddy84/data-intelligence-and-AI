# %%
list1 =[1,2,3,4,5]
sum1= sum(list1)
print(sum1)
# Out:
# 15

# %%
list2=[56,98,41,23,13]
max1 = max(list2)
min1= min(list2)
print(max1)
print(min1)
# Out:
# 98
# 13

# %%
list3 = [3,9,4,3,5,7,12,3,5]
even =0
odd =0
for i in list3:
    if i%2==0:
        even+=1
    else:
        odd+=1
print(even)
print(odd)
# Out:
# 2
# 7
