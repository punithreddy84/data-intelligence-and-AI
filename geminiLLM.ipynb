# %%
pip install google.genai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting google.genai
#   Downloading google_genai-2.9.0-py3-none-any.whl (950 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 KB 1.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /home/aceec/.local/lib/python3.10/site-packages (from google.genai) (2.32.4)
# Collecting anyio<5.0.0,>=4.8.0
#   Downloading anyio-4.14.0-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.5/123.5 KB 1.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting tenacity<9.2.0,>=8.2.3
#   Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from google.genai) (1.7.0)
# Collecting google-auth[requests]<3.0.0,>=2.48.1
#   Downloading google_auth-2.55.0-py3-none-any.whl (252 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.4/252.4 KB 3.0 MB/s eta 0:00:004.3 MB/s eta 0:00:01
# Collecting httpx<1.0.0,>=0.28.1
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 KB 1.2 MB/s eta 0:00:000:00:01
# Collecting websockets<17.0,>=13.0.0
#   Downloading websockets-16.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (183 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.8/183.8 KB 1.6 MB/s eta 0:00:002.0 MB/s eta 0:00:01
# Collecting sniffio
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting pydantic<3.0.0,>=2.12.5
#   Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.3/472.3 KB 3.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /home/aceec/.local/lib/python3.10/site-packages (from google.genai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3/dist-packages (from anyio<5.0.0,>=4.8.0->google.genai) (3.3)
# Collecting exceptiongroup>=1.0.2
#   Downloading exceptiongroup-1.3.1-py3-none-any.whl (16 kB)
# Collecting cryptography>=38.0.3
#   Downloading cryptography-49.0.0-cp39-abi3-manylinux_2_34_x86_64.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 2.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 KB 1.8 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx<1.0.0,>=0.28.1->google.genai) (2020.6.20)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 KB 1.7 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting h11>=0.16
#   Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting pydantic-core==2.46.4
#   Downloading pydantic_core-2.46.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 3.6 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting typing-inspection>=0.4.2
#   Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.28.1->google.genai) (1.26.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/aceec/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->google.genai) (3.4.2)
# Collecting cffi>=2.0.0
#   Downloading cffi-2.0.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.5/216.5 KB 2.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting pyasn1<0.7.0,>=0.6.1
#   Downloading pyasn1-0.6.3-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 KB 1.7 MB/s eta 0:00:000:00:01
# Collecting pycparser
#   Downloading pycparser-3.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 KB 950.6 kB/s eta 0:00:00 MB/s eta 0:00:01
# Installing collected packages: websockets, typing-inspection, tenacity, sniffio, pydantic-core, pycparser, pyasn1, h11, exceptiongroup, annotated-types, pydantic, pyasn1-modules, httpcore, cffi, anyio, httpx, cryptography, google-auth, google.genai
# Successfully installed annotated-types-0.7.0 anyio-4.14.0 cffi-2.0.0 cryptography-49.0.0 exceptiongroup-1.3.1 google-auth-2.55.0 google.genai-2.9.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 pyasn1-0.6.3 pyasn1-modules-0.4.2 pycparser-3.0 pydantic-2.13.4 pydantic-core-2.46.4 sniffio-1.3.1 tenacity-9.1.4 typing-inspection-0.4.2 websockets-16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install google-generativeai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting google-generativeai
#   Downloading google_generativeai-0.8.6-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.1/155.1 KB 2.3 MB/s eta 0:00:00m eta 0:00:01
# Requirement already satisfied: typing-extensions in /home/aceec/.local/lib/python3.10/site-packages (from google-generativeai) (4.15.0)
# Collecting google-ai-generativelanguage==0.6.15
#   Downloading google_ai_generativelanguage-0.6.15-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 5.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: pydantic in /home/aceec/.local/lib/python3.10/site-packages (from google-generativeai) (2.13.4)
# Requirement already satisfied: protobuf in /usr/lib/python3/dist-packages (from google-generativeai) (3.12.4)
# Collecting google-api-core
#   Downloading google_api_core-2.31.0-py3-none-any.whl (173 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.1/173.1 KB 2.6 MB/s eta 0:00:008.4 MB/s eta 0:00:01
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.197.0-py3-none-any.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 6.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: tqdm in /home/aceec/.local/lib/python3.10/site-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: google-auth>=2.15.0 in /home/aceec/.local/lib/python3.10/site-packages (from google-generativeai) (2.55.0)
# Collecting proto-plus<2.0.0dev,>=1.22.3
#   Downloading proto_plus-1.28.0-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 KB 1.5 MB/s eta 0:00:00
# Collecting protobuf
#   Downloading protobuf-5.29.6-cp38-abi3-manylinux2014_x86_64.whl (320 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.5/320.5 KB 3.7 MB/s eta 0:00:00m eta 0:00:010:01
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/aceec/.local/lib/python3.10/site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /home/aceec/.local/lib/python3.10/site-packages (from google-auth>=2.15.0->google-generativeai) (49.0.0)
# Collecting googleapis-common-protos<2.0.0,>=1.63.2
#   Downloading googleapis_common_protos-1.75.0-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.6/300.6 KB 4.6 MB/s eta 0:00:008.3 MB/s eta 0:00:01
# Collecting requests<3.0.0,>=2.33.0
#   Downloading requests-2.34.2-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 KB 955.7 kB/s eta 0:00:001m960.9 kB/s eta 0:00:01
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/lib/python3/dist-packages (from google-api-python-client->google-generativeai) (0.20.2)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0
#   Downloading google_auth_httplib2-0.4.0-py3-none-any.whl (9.5 kB)
# Collecting uritemplate<5,>=3.0.1
#   Downloading uritemplate-4.2.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/aceec/.local/lib/python3.10/site-packages (from pydantic->google-generativeai) (2.46.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/aceec/.local/lib/python3.10/site-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/aceec/.local/lib/python3.10/site-packages (from pydantic->google-generativeai) (0.4.2)
# Requirement already satisfied: cffi>=2.0.0 in /home/aceec/.local/lib/python3.10/site-packages (from cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai) (2.0.0)
# Collecting grpcio-status<2.0.0,>=1.41.0
#   Downloading grpcio_status-1.81.1-py3-none-any.whl (14 kB)
# Collecting grpcio<2.0.0,>=1.41.0
#   Downloading grpcio-1.81.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 3.6 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/lib/python3/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (2.4.7)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /home/aceec/.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.33.0->google-api-core->google-generativeai) (3.3)
# Collecting certifi>=2023.5.7
#   Downloading certifi-2026.6.17-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 KB 1.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/aceec/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.33.0->google-api-core->google-generativeai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.33.0->google-api-core->google-generativeai) (1.26.5)
# Requirement already satisfied: pycparser in /home/aceec/.local/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai) (3.0)
# Collecting grpcio-status<2.0.0,>=1.41.0
#   Downloading grpcio_status-1.81.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.80.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.78.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.76.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.75.1-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.75.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.74.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.73.1-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.73.0-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.72.2-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.72.1-py3-none-any.whl (14 kB)
#   Downloading grpcio_status-1.71.2-py3-none-any.whl (14 kB)
# Installing collected packages: uritemplate, protobuf, grpcio, certifi, requests, proto-plus, googleapis-common-protos, grpcio-status, google-auth-httplib2, google-api-core, google-api-python-client, google-ai-generativelanguage, google-generativeai
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# Successfully installed certifi-2026.6.17 google-ai-generativelanguage-0.6.15 google-api-core-2.31.0 google-api-python-client-2.197.0 google-auth-httplib2-0.4.0 google-generativeai-0.8.6 googleapis-common-protos-1.75.0 grpcio-1.81.1 grpcio-status-1.71.2 proto-plus-1.28.0 protobuf-5.29.6 requests-2.34.2 uritemplate-4.2.0

# %%
from google import genai

# %%
API_KEY =""

# %%
client = genai.Client(api_key=API_KEY)

# %%
promt="tiger"

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=promt
)

print(response.text)
# Out:
# The tiger (Panthera tigris) is the largest living cat species and a magnificent predator!
#
# Here are some key facts about tigers:
#
# *   **Appearance:** They are easily recognized by their dark vertical stripes on reddish-orange fur with a lighter underside. Each tiger's stripe pattern is unique, like human fingerprints.
# *   **Habitat:** Native to a wide range of habitats across Asia, from the Siberian taiga to tropical forests and grasslands.
# *   **Diet:** They are carnivores, primarily preying on large ungulates like deer and wild boar.
# *   **Behavior:** Tigers are solitary animals, generally nocturnal, and excellent swimmers. They are also powerful and stealthy hunters.
# *   **Conservation Status:** Sadly, all subspecies of tigers are endangered, with populations significantly threatened by habitat loss, poaching for their body parts, and human-wildlife conflict.
# *   **Subspecies:** There are several recognized subspecies, including the Bengal tiger, Siberian (Amur) tiger, Sumatran tiger, Indochinese tiger, and Malayan tiger. Three subspecies have gone extinct in the last century (Caspian, Javan, and Bali tigers).
#
# They are iconic symbols of strength, courage, and beauty in many cultures. What about tigers are you most interested in?
